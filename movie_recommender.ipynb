# %% [markdown]
# #### Problem statement:
# Our goal is to develop a machine learning-based movie recommendation system that can predict and recommend movies to users based on their unique preferences. This system would use Term Frequency-Inverse Document Frequency (TF-IDF) vectorization technique to transform text data into meaningful numerical vectors, and cosine similarity to compute the similarity between these vectors.

# %% [markdown]
# #### Importing the necessary libraries:

# %%
import pandas as pd
import numpy as np
import ast
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pickle

# %% [markdown]
# #### Loading the dataset:

# %%
movies = pd.read_csv("tmdb_5000_movies.csv")
credits = pd.read_csv("tmdb_5000_credits.csv")
df = movies.merge(credits, on="title")

# %%
df.sample(5)
# Out:
#          budget                                             genres  \
# 4275          0                    [{"id": 37, "name": "Western"}]
# 7     280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3903    3000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 3776          0  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4686     450000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
#
#                                                homepage      id  \
# 4275                                                NaN  218500
# 7     http://marvel.com/movies/movie/193/avengers_ag...   99861
# 3903                                                NaN     261
# 3776                                                NaN   15122
# 4686                   http://www.malevolencemovie.com/   54702
#
#                                                keywords original_language  \
# 4275                                                 []                en
# 7     [{"id": 8828, "name": "marvel comic"}, {"id": ...                en
# 3903  [{"id": 30, "name": "individual"}, {"id": 236,...                en
# 3776  [{"id": 9817, "name": "behind the scenes"}, {"...                en
# 4686  [{"id": 1562, "name": "hostage"}, {"id": 6259,...                en
#
#                      original_title  \
# 4275  The Ballad of Gregorio Cortez
# 7           Avengers: Age of Ultron
# 3903          Cat on a Hot Tin Roof
# 3776                    Love Stinks
# 4686                    Malevolence
#
#                                                overview  popularity  \
# 4275  The entire cause of the problem evolves from t...    0.592821
# 7     When Tony Stark tries to jumpstart a dormant p...  134.279229
# 3903  Brick, an alcoholic ex-football player, drinks...   16.553594
# 3776  A movie about a relationship...that's worse th...    3.347885
# 4686  It's ten years after the kidnapping of Martin ...    1.077321
#
#                                    production_companies  ... runtime  \
# 4275  [{"name": "Moctesuma Esparza Productions", "id...  ...   104.0
# 7     [{"name": "Marvel Studios", "id": 420}, {"name...  ...   141.0
# 3903  [{"name": "Avon Production", "id": 100}, {"nam...  ...   108.0
# 3776                                                 []  ...    94.0
# 4686                                                 []  ...    90.0
#
#                                        spoken_languages    status  \
# 4275           [{"iso_639_1": "en", "name": "English"}]  Released
# 7              [{"iso_639_1": "en", "name": "English"}]  Released
# 3903           [{"iso_639_1": "en", "name": "English"}]  Released
# 3776  [{"iso_639_1": "pt", "name": "Portugu\u00eas"}...  Released
# 4686  [{"iso_639_1": "pl", "name": "Polski"}, {"iso_...  Released
#
#                                                 tagline  \
# 4275                                                NaN
# 7                                   A New Age Has Come.
# 3903  Just one pillow on her bed ... and just one de...
# 3776                                                NaN
# 4686                                                NaN
#
#                               title vote_average vote_count movie_id  \
# 4275  The Ballad of Gregorio Cortez          0.0          0   218500
# 7           Avengers: Age of Ultron          7.3       6767    99861
# 3903          Cat on a Hot Tin Roof          7.6        165      261
# 3776                    Love Stinks          5.4         11    15122
# 4686                    Malevolence          4.9         14    54702
#
#                                                    cast  \
# 4275  [{"cast_id": 3, "character": "Boone Chate", "c...
# 7     [{"cast_id": 76, "character": "Tony Stark / Ir...
# 3903  [{"cast_id": 4, "character": "Maggie", "credit...
# 3776  [{"cast_id": 1, "character": "Seth Winnick", "...
# 4686  [{"cast_id": 1002, "character": "Samantha Harr...
#
#                                                    crew
# 4275  [{"credit_id": "52fe4e4ec3a368484e219717", "de...
# 7     [{"credit_id": "55d5f7d4c3a3683e7e0016eb", "de...
# 3903  [{"credit_id": "52fe422fc3a36847f800a6f7", "de...
# 3776  [{"credit_id": "52fe463c9251416c75071af9", "de...
# 4686  [{"credit_id": "52fe48abc3a36847f817354b", "de...
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Data cleaning and preprocessing:

# %%
#Information about the dataset:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
#  15  status                4809 non-null   object
#  16  tagline               3965 non-null   object
#  17  title                 4809 non-null   object
#  18  vote_average          4809 non-null   float64
#  19  vote_count            4809 non-null   int64
#  20  movie_id              4809 non-null   int64
#  21  cast                  4809 non-null   object
#  22  crew                  4809 non-null   object
# dtypes: float64(3), int64(5), object(15)
# memory usage: 864.2+ KB

# %%
#Removing the unnecessary columns:
df = df[["genres", "id", "keywords", "title", "overview", "cast", "crew"]]

# %%
#Checking for and handling missing entries:
df.isnull().sum()
df.dropna(inplace=True)

# %%
#Checking for and handling duplicates:
df.duplicated().sum()
# Out:
# 0

# %%
#Function to extract the list of genres and list of keywords:
def genre_keyword_converter(obj):
    L = []
    for d in ast.literal_eval(obj):
        L.append(d["name"])
    return L

df["genres"] = df["genres"].apply(genre_keyword_converter)
df["keywords"] = df["keywords"].apply(genre_keyword_converter)

# %%
#Function to extract the list of cast:
def cast_converter(obj):
    L = []
    c=0
    for d in ast.literal_eval(obj):
        if c==3:
            break
        L.append(d["name"])
        c += 1
    return L

df["cast"] = df["cast"].apply(cast_converter)

# %%
#Function to extract the name of the director:
def crew_converter(obj):
    for d in ast.literal_eval(obj):
        if d["job"] == "Director":
            return [d["name"]]
        
df["director"] = df["crew"].apply(crew_converter)
df = df.drop(columns="crew")

# %%
#Converting the "overview" column to a list:
df["overview"] = df["overview"].apply(lambda x: x.split(" "))

# %%
#Eliminating spaces between keywords/tags:
def replace(L):
    if not L:
        return []
    else:
        return [i.replace(" ", "") for i in L]
df["genres"] = df["genres"].apply(replace)
df["keywords"] = df["keywords"].apply(replace)
df["director"] = df["director"].apply(replace)
df["cast"] = df["cast"].apply(replace)

# %%
df.sample(10)
# Out:
#                                      genres      id  \
# 1568                        [Drama, Comedy]    2755
# 928                                 [Drama]   60308
# 4482       [Horror, Drama, Thriller, Crime]   13429
# 3716                      [Drama, Thriller]    4550
# 694      [Action, Drama, Mystery, Thriller]    2501
# 798                                [Comedy]  116741
# 2074                         [Crime, Drama]    1646
# 596   [Action, Adventure, Comedy, Thriller]    8427
# 2730             [Action, Comedy, Thriller]   70829
# 4555              [Action, Drama, Thriller]  253626
#
#                                                keywords  \
# 1568  [wifehusbandrelationship, channelsurfing, mull...
# 928   [underdog, basedonnovel, baseball, teamwork, s...
# 4482                                                 []
# 3716                                  [independentfilm]
# 694   [paris, barcelonaspain, assassin, basedonnovel...
# 798   [jobinterview, lossofjob, intern, referencetog...
# 2074  [blackpeople, basedonnovel, holocaust, ghetto,...
# 596   [budapest, kidnapping, boxer, secretagent, lib...
# 2730                                                 []
# 4555  [pilot, suspicion, drone, u.s.military, airfor...
#
#                             title  \
# 1568                About Schmidt
# 928                     Moneyball
# 4482                 Donkey Punch
# 3716  Sympathy for Lady Vengeance
# 694           The Bourne Identity
# 798                The Internship
# 2074              Freedom Writers
# 596                         I Spy
# 2730           The Last Godfather
# 4555                    Good Kill
#
#                                                overview  \
# 1568  [66-year-old, Warren, Schmidt, is, a, retired,...
# 928   [The, story, of, Oakland, Athletics, general, ...
# 4482  [Three, hot, girls,, four, guys,, and, one, me...
# 3716  [After, a, 13-year, imprisonment, for, the, ki...
# 694   [Wounded, to, the, brink, of, death, and, suff...
# 798   [Two, recently, laid-off, men, in, their, 40s,...
# 2074  [A, young, teacher, inspires, her, class, of, ...
# 596   [When, the, Switchblade,, the, most, sophistic...
# 2730  [Young-goo, the, son, of, mafia, boss, Don, Ca...
# 4555  [In, the, shadowy, world, of, drone, warfare,,...
#
#                                              cast              director
# 1568       [JackNicholson, KathyBates, HopeDavis]      [AlexanderPayne]
# 928   [BradPitt, JonahHill, PhilipSeymourHoffman]       [BennettMiller]
# 4482  [NicholaBurley, SianBreckin, JaimeWinstone]       [OllyBlackburn]
# 3716    [ChoiMin-sik, LeeYoung-ae, KwonYea-young]       [ParkChan-wook]
# 694       [MattDamon, FrankaPotente, ChrisCooper]           [DougLiman]
# 798          [OwenWilson, VinceVaughn, RoseByrne]           [ShawnLevy]
# 2074    [HilarySwank, ScottGlenn, ImeldaStaunton]  [RichardLaGravenese]
# 596       [EddieMurphy, OwenWilson, FamkeJanssen]         [BettyThomas]
# 2730       [HarveyKeitel, JasonMewes, BlakeClark]       [ShimHyung-Rae]
# 4555       [EthanHawke, JanuaryJones, ZoëKravitz]        [AndrewNiccol]

# %%
#Concatenating keywords into the "tags" column and dropping unnecessary columns:
df["tags"] = df["keywords"] + df["overview"] + df["cast"] + df["director"] + df["genres"]
df.drop(columns=["keywords", "genres", "overview", "director", "cast"], inplace=True)

# %%
df["tags"] = df["tags"].apply(lambda x: " ".join(x))
df ["tags"] = df["tags"].apply(lambda x: x.lower())

# %%
#Function to perform stemming and remove stopwords from a piece of text:
stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))
def preprocess_text(text):
    words = word_tokenize(text)
    processed_words = [stemmer.stem(word) for word in words if word not in stop_words]
    return ' '.join(processed_words)

df["tags"] = df["tags"].apply(preprocess_text)

# %%
df.sample(10)
# Out:
#           id                  title  \
# 377     4477        The Devil's Own
# 3839     573                 Frenzy
# 4413  242083                   Hits
# 1936   20309        Say It Isn't So
# 3925   15158            Phantasm II
# 4515   75986           Love Letters
# 781     2309               Inkheart
# 3241     773   Little Miss Sunshine
# 1731   10383             Lost Souls
# 2906  345003  10 Days in a Madhouse
#
#                                                    tags
# 377   newyork terrorist anonym northernireland frank...
# 3839  londonengland rape polic suspens serialkil ser...
# 4413  talent delus fame teenag viralvideo talentless...
# 1936  boy meet girl ; boy fall love ( wild , non-sto...
# 3925  portal undertak evil tallman sentin mike , rel...
# 4515  obsess radio nuditi letter love romanc lingeri...
# 781   book fairytal eavesdrop adventur writer'sblock...
# 3241  california brothersisterrelationship wifehusba...
# 1731  pedophilia daughter anti-christ incest small g...
# 2906  undercov insaneasylum report nelli bli , 23 ye...

# %%
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(df["tags"])
cs = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %% [markdown]
# #### Exporting the cosine similarity table and the processed dataframe:

# %%
pickle.dump(df.to_dict(), open("movies.pkl", "wb"))
pickle.dump(cs, open("cs.pkl", "wb"))
